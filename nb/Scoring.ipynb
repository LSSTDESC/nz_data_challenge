# %% [markdown]
# # Notebook to make scoring plots

# %% [markdown]
# #### Standard imports

# %%
import tables_io
import numpy as np
import os
import matplotlib.pyplot as plt
from nz_data_challenge import submit_utils, metrics, utils, evaluation
from pathlib import Path

# %% [markdown]
# #### Paths

# %%
submissions = ['example']
test_only = False
if test_only:
    results_dir = '../results_test'
else:
    results_dir = '../results'

# %% [markdown]
# #### Read the metrics yamls files and build a dataframe

# %%
dataframe = evaluation.build_summary_stats_dataframe(
    submissions,
    results_dir,
)

# %% [markdown]
# #### Score all the metrics

# %%
scores_df = evaluation.build_scores_dataframe(dataframe)

# %% [markdown]
# #### Plotting the scoring matrix

# %%
score_matrix = evaluation.extract_score_matrix(scores_df, submissions[0])
_ = evaluation.plot_score_matrix(score_matrix)

# %% [markdown]
# #### Get the dataframe of per-taskset scores

# %%
all_scores = evaluation.get_all_scores(scores_df, submissions)
all_scores

# %% [markdown]
# #### Plot various metrics, showing the scoring bands

# %%
_ = evaluation.make_strip_plot(dataframe, submissions, 'accuracy')

# %%
_ = evaluation.make_strip_plot(dataframe, submissions, 'balanced_accuracy')

# %%
_ = evaluation.make_strip_plot(dataframe, submissions, 'cohens_kappa')

# %%
_ = evaluation.make_strip_plot(dataframe, submissions, 'log_loss')

# %%
_ = evaluation.make_strip_plot(dataframe, submissions, 'mutual_info')

# %%
_ = evaluation.make_strip_plot(dataframe, submissions, 'rms0_delta_mean')

# %%
_ = evaluation.make_strip_plot(dataframe, submissions, 'rms0_delta_std')

# %%
_ = evaluation.make_strip_plot(dataframe, submissions, 'total_information_loss')
